# %%
# data_source = ColumnDataSource(data=dict(
#     x=list(df['merclong']),
#     y=df['merclat'],
#     name=df['name'],
#     price=list(df['price1']),
#     label=df['price1']
    
# ))

# for data,name, color in zip([df[df['price1']=='$'],
#                               df[df['price1']=='$$'],
#                               df[df['price1']=='$$$'],
#                               df[df['price1']=='$$$$']],['$','$$','$$$','$$$$'], RdYlGn4):
#     df = data
#     p.scatter('x', 'y',source=data_source, color=color, alpha=0.8,size=2.6, legend_label=name)


# hover = p.select_one(HoverTool)
# hover.point_policy = "follow_mouse"
# hover.tooltips = [
#     ("Name", "@name"),
#     ("Price","@price")]

# p.legend.click_policy="hide"


# #data_source = ColumnDataSource(data=dict(
# #     x=df['merclong'],
# #     y=df['merclat'],
# #     name=df['name'],
# #     price=df['price1']))
    
    

 

# output_notebook()
# show(p)

# %%
# data_source = ColumnDataSource(data=dict(
#     x=df['merclong'],
#     y=df['merclat'],
#     name=df['name'],
#     price=list(df['price1'])))

# for data, name, color in zip([df[df['price1']=='$'],
#                               df[df['price1']=='$$'],
#                               df[df['price1']=='$$$'],
#                               df[df['price1']=='$$$$']], ['$','$$','$$$','$$$$'], RdYlGn4):
#     df = data
#     p.scatter(df['merclong'], df['merclat'], color=color, alpha=0.8,size=2.6, legend_label=name)

# p.legend.click_policy="hide"


# #data_source = ColumnDataSource(data=dict(
# #     x=df['merclong'],
# #     y=df['merclat'],
# #     name=df['name'],
# #     price=df['price1']))
    
    
# hover = p.select_one(HoverTool)
# hover.point_policy = "follow_mouse"
# hover.tooltips = [
#     ("State", "@price")]
 

# output_notebook()
# show(p)
