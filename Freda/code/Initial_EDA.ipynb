# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('../data/raw.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                      id                            alias  \
# 0           0  C3spvfEd8JQJie-yixRgpQ          com-tam-ninh-kieu-bronx
# 1           1  b6jOwyX4iaagw8YjXqq1sA         antonios-trattoria-bronx
# 2           2  ciHt5n5rmpby1YcC_6JVrg           bronx-alehouse-bronx-2
# 3           3  HeR2gHJbP5CN69UsVCtMGg  new-york-botanical-garden-bronx
# 4           4  KAxYFGyOQ7ysCmYmh8jKtw           the-bronx-public-bronx
#
#                         name  \
# 0          Com Tam Ninh Kieu
# 1        Antonio's Trattoria
# 2             Bronx Alehouse
# 3  New York Botanical Garden
# 4           The Bronx Public
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/e0yxD8...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/VnG_ke...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/IHoWZm...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/6TZIAs...      False
# ...

# %%
ast.literal_eval(df['location'][1])['zip_code']
# Out:
# '10458'

# %%
df['location'][1]
# Out:
# "{'address1': '2370 Belmont Ave', 'address2': None, 'address3': '', 'city': 'Bronx', 'zip_code': '10458', 'country': 'US', 'state': 'NY', 'display_address': ['2370 Belmont Ave', 'Bronx, NY 10458']}"

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30293, step=1)

# %%
import ast
df['zip_code'] = [ast.literal_eval(df['location'][i])['zip_code'] for i in df.index]

# %%
df
# Out:
#        Unnamed: 0                      id                            alias  \
# 0               0  C3spvfEd8JQJie-yixRgpQ          com-tam-ninh-kieu-bronx
# 1               1  b6jOwyX4iaagw8YjXqq1sA         antonios-trattoria-bronx
# 2               2  ciHt5n5rmpby1YcC_6JVrg           bronx-alehouse-bronx-2
# 3               3  HeR2gHJbP5CN69UsVCtMGg  new-york-botanical-garden-bronx
# 4               4  KAxYFGyOQ7ysCmYmh8jKtw           the-bronx-public-bronx
# ...           ...                     ...                              ...
# 30288       30288  CKRk-OfTu7Zk58klwrCzuA            pio-pio-rico-brooklyn
# 30289       30289  DcZAtvCdGrd_HItAiPcWfQ    coney-island-pinball-brooklyn
# 30290       30290  0i9cSBxCggVT8toJB3gPBg        mermaid-1-stop-brooklyn-2
# 30291       30291  WpyWwShlJ5pXW8MERFFfXw  ocean-front-restaurant-brooklyn
# 30292       30292  0skCmtTfuQFZF0P7dAxcJg       k-and-e-fast-food-brooklyn
#
#                             name  \
# ...
